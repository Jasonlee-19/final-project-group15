# %% [markdown]
# # 'Alcohol Effects On Study' Data Set
# ### --Survey about the effect of family background on math achievement

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import math

df = pd.read_csv('Maths.csv')
# Out:
# C:\Users\13045\AppData\Local\Temp\ipykernel_5536\3743951761.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu  avedu     Mjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4    4.0  at_home  ...
# 1     GP   F   17       U     GT3       T     1     1    1.0  at_home  ...
# 2     GP   F   15       U     LE3       T     1     1    1.0  at_home  ...
# 3     GP   F   15       U     GT3       T     4     2    3.0   health  ...
# 4     GP   F   16       U     GT3       T     3     3    3.0    other  ...
#
#   freetime goout Dalc  Walc  health  absences  G1  G2  G3 avegrade
# 0        3     4    1     1       3         6   5   6   6     5.67
# 1        3     3    1     1       3         4   5   5   6     5.33
# 2        3     2    2     3       3        10   7   8  10     8.33
# 3        2     2    1     1       5         2  15  14  15    14.67
# 4        3     2    1     2       5         4   6  10  10     8.67
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Q1: Effect of average parental education level on math achievement

# %%
df.avedu.value_counts()
# Out:
# 2.0    72
# 4.0    70
# 3.0    64
# 3.5    58
# 2.5    47
# 1.5    43
# 1.0    39
# 0.5     2
# Name: avedu, dtype: int64

# %%
df.groupby('avedu')['avegrade'].mean().plot.line()
# Out:
# <AxesSubplot: xlabel='avedu'>

# %% [markdown]
# ### Q2: The impact of willing to take higher education on academic performance

# %%
df.groupby('higher')['avegrade'].mean().plot.bar()
# Out:
# <AxesSubplot: xlabel='higher'>

# %% [markdown]
# ### *Alcohol consumption of student

# %%
# Pie chart about workday alcohol consumption of student
df['Dalc'].value_counts(normalize=True).plot.pie(autopct='%.2f%%')
plt.title('Workday alcohol consumption of student\n--from [1:very low] to [5:very high]')
# Out:
# Text(0.5, 1.0, 'Workday alcohol consumption of student\n--from [1:very low] to [5:very high]')

# %%
# Pie chart about weekend alcohol consumption of student
df['Walc'].value_counts(normalize=True).plot.pie(autopct='%.2f%%')
plt.title('Weekend alcohol consumption of student\n--from [1:very low] to [5:very high]')
# Out:
# Text(0.5, 1.0, 'Weekend alcohol consumption of student\n--from [1:very low] to [5:very high]')
